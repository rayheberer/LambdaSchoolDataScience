# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.linspace(-10, 10)
y = np.sin(x)

# %%
df = pd.DataFrame([x, y]).T
df.columns = ['x', 'y']
df.head()
# Out:
#            x         y
# 0 -10.000000  0.544021
# 1  -9.591837  0.166283
# 2  -9.183673 -0.238775
# 3  -8.775510 -0.604603
# 4  -8.367347 -0.871097

# %%
plt.plot(x, y);

# %%
print("Python data stack is fully operational >:)")
# Out:
# Python data stack is fully operational >:)
